# %%
from PIL import Image

image = Image.open('ai_guy.webp')
image.show()

# %%
new_size = (308,308)
resized = image.resize(new_size)
resized.save('ai_guy_small.webp')
resized
# Out:
# <PIL.Image.Image image mode=RGB size=308x308>

# %%
def split_and_merge(image: Image) -> Image:
    image_r, image_g, image_b = image.split()
    #modifikuojam
    merged_image = Image.merge("RGB", (image_r, image_g, image_b))
    return merged_image

procesed = split_and_merge(image)
image.point()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 8
#       5     return merged_image
#       7 procesed = split_and_merge(image)
# ----> 8 image.point()
#
# TypeError: Image.point() missing 1 required positional argument: 'lut'
